# %%
import numpy as np
import pandas as pd

# %%
data = np.loadtxt("input", dtype="str")
print(data)
# Out:
# [['7227Q' '52']
#  ['67Q64' '732']
#  ['33Q33' '573']
#  ...
#  ['27276' '847']
#  ['22954' '425']
#  ['TK4JT' '819']]

# %%
five_of_a_kind = []
four_of_a_kind = []
full_house = []
three_of_a_kind = []
two_pair = []
one_pair = []
high_card = []

# %%
for entry in data:
    print(entry)
# Out:
# ['7227Q' '52']
# ['67Q64' '732']
# ['33Q33' '573']
# ['58ATQ' '939']
# ['93K53' '840']
# ['55AJ8' '496']
# ['6ATAT' '863']
# ['26J77' '1']
# ['TTQAT' '381']
# ['2J2J2' '322']
# ['342Q2' '409']
# ['3444Q' '864']
# ['77J67' '31']
# ['772QJ' '796']
# ['5388J' '956']
# ['7JJ7J' '88']
# ['5Q555' '626']
# ['77AK8' '588']
# ['J2222' '661']
# ['36T93' '934']
# ['5Q365' '343']
# ['K3K3K' '283']
# ['5959A' '537']
# ['44477' '560']
# ['6AA5K' '208']
# ['5J445' '262']
# ['28228' '61']
# ['646A6' '503']
# ['KK4Q8' '471']
# ['A426T' '500']
# ['AQ9JA' '643']
# ['J784T' '348']
# ['22J48' '6']
# ['A5AJ5' '220']
# ['62235' '545']
# ['84JJJ' '206']
# ['48464' '669']
# ['44844' '637']
# ['Q8537' '969']
# ['95663' '751']
# ['JTQK7' '305']
# ['33TTT' '335']
# ['4T925' '32']
# ['9777Q' '738']
# ['2QQ66' '971']
# ['TQQ9T' '657']
# ['69437' '176']
# ['2555J' '849']
# ['55AAA' '26']
# ['94TT4' '531']
# ['89T66' '55']
# ['387J8' '663']
# ['KKKKJ' '198']
# ['K4KK4' '870']
# ['622J2' '330']
# ['6283A' '337']
# ...
